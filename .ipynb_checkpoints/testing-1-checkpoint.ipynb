# %%
# niew npz
import os
import numpy as np

data = np.load('trained_models/attention_concat_time/epoch_times.npz')
data

# %% [markdown]
# ## Preprocessing

# %%
# from pyhealth.datasets import MIMIC3Dataset

# mimic3_ds = MIMIC3Dataset(
#         root="https://storage.googleapis.com/pyhealth/Synthetic_MIMIC-III/",
#         tables=["DIAGNOSES_ICD", "PROCEDURES_ICD", "PRESCRIPTIONS"],
#         code_mapping={"NDC": ("ATC", {"target_kwargs": {"level": 3}})},
# )

# # we show the statistics below.
# mimic3_ds
# Out:
# Parsing PATIENTS and ADMISSIONS: 100%|██████████| 49993/49993 [01:56<00:00, 427.41it/s]
# Parsing DIAGNOSES_ICD: 100%|██████████| 52354/52354 [00:11<00:00, 4657.02it/s]
# Parsing PROCEDURES_ICD: 100%|██████████| 45769/45769 [00:07<00:00, 5772.36it/s]
# Parsing PRESCRIPTIONS: 100%|██████████| 50710/50710 [03:05<00:00, 272.76it/s]
# Mapping codes: 100%|██████████| 49993/49993 [01:42<00:00, 486.53it/s]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\azaan\\OneDrive\\Documents\\GitHub\\CS598-Healthcare-Project'

# %%
# having issues because of lowercase headers in the mimic-iii file, so i have some code
# to make all the headers into capital letters here:

import os
import csv

# Specify the path to your folder of CSV files
folder_path = 'C:/Users/azaan/OneDrive/Documents/GitHub/CS598-Healthcare-Project/MIMIC-III Clinical Database/'

# Loop through each CSV file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        # Open the CSV file for reading
        with open(file_path, 'r') as csv_file:
            reader = csv.reader(csv_file)

            # Create a new list to hold the capitalized header row
            new_rows = []

            # Loop through each row in the CSV file
            for i, row in enumerate(reader):

                # Capitalize the header row
                if i == 0:
                    new_row = [cell.upper() for cell in row]
                    new_rows.append(new_row)

                # Keep all other rows the same
                else:
                    new_rows.append(row)

        # Open the CSV file for writing
        with open(file_path, 'w', newline='') as csv_file:
            writer = csv.writer(csv_file)

            # Write the new rows to the CSV file
            writer.writerows(new_rows)

# %%
# I am going to tr and run some files related_code
# Order is important so I will write the order I do them

#1: preproceeing_ICU_PAT_ADMIT.py
# !python related_code\\preprocessing_ICU_PAT_ADMIT.py
# Out:
# Load ICU stays...
# -----------------------------------------
# Load patients...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load services...
# -----------------------------------------
# Link icustays and patients tables...
# Compute number of recent admissions...
# -----------------------------------------
# Link icu_pat and admissions tables...
# SUBJECT_ID               0
# HADM_ID                  0
# ICUSTAY_ID               0
# INTIME                   0
# OUTTIME                  0
# LOS                      0
# GENDER_M                 0
# NUM_RECENT_ADMISSIONS    0
# AGE                      0
# POSITIVE                 0
# ADMITTIME                0
# ADMISSION_TYPE           0
# ADMISSION_LOCATION       0
# INSURANCE                0
# MARITAL_STATUS           5
# ETHNICITY                0
# dtype: int64
# Some data cleaning on admissions...
# -----------------------------------------
# Link services table...
# -----------------------------------------
# Total pos 11
# Total neg 70
# count    11.000000
# mean      3.091173
# std       1.831840
# min       1.147400
# 25%       1.937150
# 50%       2.825800
# 75%       3.591800
# max       7.902000
# Name: LOS, dtype: float64
# count    70.000000
# mean      3.683767
# std       5.383570
# min       0.654900
# 25%       1.179175
# 50%       1.902050
# 75%       3.282575
# max      31.123501
# Name: LOS, dtype: float64
# count    11.000000
# mean      0.432139
# std       0.839179
# min       0.000289
# 25%       0.000718
# 50%       0.001065
# 75%       0.482083
# max       2.803368
# Name: PRE_ICU_LOS, dtype: float64
# count    70.000000
# mean      0.476307
# std       1.223935
# min       0.000000
# 25%       0.000885
# 50%       0.001337
# 75%       0.138177
# max       5.690949
# Name: PRE_ICU_LOS, dtype: float64
# count    11.0
# mean     71.4
# std      13.6
# min      53.5
# 25%      58.5
# 50%      77.0
# 75%      82.4
# max      91.5
# Name: AGE, dtype: float64
# count    70.0
# mean     70.3
# std      13.6
# min      27.9
# 25%      63.8
# 50%      70.8
# 75%      80.8
# max      91.5
# Name: AGE, dtype: float64
# count    11.0
# mean      0.7
# std       1.5
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       1.0
# max       5.0
# Name: NUM_RECENT_ADMISSIONS, dtype: float64
# count    70.0
# mean      0.6
# std       1.3
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       1.0
# max       6.0
# Name: NUM_RECENT_ADMISSIONS, dtype: float64
#    COUNTS  PERC
# 1       9  81.8
# 0       2  18.2
#    COUNTS  PERC
# 1      41  58.6
# 0      29  41.4
#                COUNTS   PERC
# Other/Unknown      11  100.0
#                COUNTS   PERC
# Other/Unknown      70  100.0
#                COUNTS   PERC
# Other/Unknown      11  100.0
#                COUNTS   PERC
# Other/Unknown      70  100.0
#                COUNTS   PERC
# Other/Unknown      11  100.0
#                COUNTS   PERC
# Other/Unknown      70  100.0
#                COUNTS   PERC
# Other/Unknown      11  100.0
#                COUNTS   PERC
# Other/Unknown      70  100.0
#    COUNTS  PERC
# 0      10  90.9
# 1       1   9.1
#    COUNTS  PERC
# 0      64  91.4
# 1       6   8.6
# -----------------------------------------
# Save...
#   0%|          | 0/77 [00:00<?, ?it/s]C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\tqdm\std.py:1195: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for obj in iterable:
#
# 100%|##########| 77/77 [00:00<00:00, 961.06it/s]

# %%
#2: preprocessing chart perscriptions
# !python related_code\\preprocessing_DIAGNOSES_PROCEDURES.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load diagnoses and procedures...
# -----------------------------------------
# Link diagnoses/procedures and admissions tables...
# Link diagnoses/procedures and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
#3: preprocessing_reduce_charts.py
# !python related_code\\preprocessing_reduce_charts.py
# Out:
# -----------------------------------------
# 0it [00:00, ?it/s]
# 1it [00:00,  1.33it/s]
# 1it [00:00,  1.33it/s]
# Load item definitions
# GCS_EYE_OPENING
#        ITEMID                LABEL UNITNAME
# 184       184          Eye Opening      NaN
# 9520   220739    GCS - Eye Opening      NaN
# 11329  226756  GCSEyeApacheIIValue      NaN
# 11500  227011      GCSEye_ApacheIV      NaN
# GCS_VERBAL_RESPONSE
#        ITEMID                   LABEL UNITNAME
# 671       723         Verbal Response      NaN
# 9639   223900   GCS - Verbal Response      NaN
# 11331  226758  GCSVerbalApacheIIValue      NaN
# 11503  227014      GCSVerbal_ApacheIV      NaN
# GCS_MOTOR_RESPONSE
#        ITEMID                  LABEL UNITNAME
# 417       454         Motor Response      NaN
# 9640   223901   GCS - Motor Response      NaN
# 11330  226757  GCSMotorApacheIIValue      NaN
# 11501  227012      GCSMotor_ApacheIV      NaN
# GCS_TOTAL
#        ITEMID             LABEL UNITNAME
# 198       198         GCS Total      NaN
# 11328  226755  GcsApacheIIScore     None
# DIASTOLIC_BP
#        ITEMID                                  LABEL UNITNAME
# 4826     8364                        ABP [Diastolic]      NaN
# 4830     8368                Arterial BP [Diastolic]      NaN
# 4902     8440                  Manual BP [Diastolic]      NaN
# 4903     8441                        NBP [Diastolic]      NaN
# 4952     8502                    BP Cuff [Diastolic]      NaN
# 4953     8503                BP Left Arm [Diastolic]      NaN
# 4956     8506               BP Right Arm [Diastolic]      NaN
# 5016     8555             Arterial BP #2 [Diastolic]      NaN
# 9529   220051      Arterial Blood Pressure diastolic     mmHg
# 9547   220180  Non Invasive Blood Pressure diastolic     mmHg
# 10236  224643   Manual Blood Pressure Diastolic Left     mmHg
# 10500  225310                       ART BP Diastolic     mmHg
# 11430  227242  Manual Blood Pressure Diastolic Right     mmHg
# SYSTOLIC_BP
#        ITEMID                                 LABEL UNITNAME
# 31          6                        ABP [Systolic]      NaN
# 56         51                Arterial BP [Systolic]      NaN
# 407       442                  Manual BP [Systolic]      NaN
# 418       455                        NBP [Systolic]      NaN
# 928      3313                    BP Cuff [Systolic]      NaN
# 930      3315                BP Left Arm [Systolic]      NaN
# 936      3321               BP Right Arm [Systolic]      NaN
# 4324     6701             Arterial BP #2 [Systolic]      NaN
# 9528   220050      Arterial Blood Pressure systolic     mmHg
# 9546   220179  Non Invasive Blood Pressure systolic     mmHg
# 9862   224167   Manual Blood Pressure Systolic Left     mmHg
# 10499  225309                       ART BP Systolic     mmHg
# 11431  227243  Manual Blood Pressure Systolic Right     mmHg
# MEAN_BP
#        ITEMID                             LABEL UNITNAME
# 57         52                  Arterial BP Mean      NaN
# 408       443              Manual BP Mean(calc)      NaN
# 419       456                          NBP Mean      NaN
# 927      3312                    BP Cuff [Mean]      NaN
# 929      3314                BP Left Arm [Mean]      NaN
# 935      3320               BP Right Arm [Mean]      NaN
# 3463     2293                            ART BP      NaN
# 3464     2294                          ART MEAN      NaN
# 3691     2647                          art mean      NaN
# 4268     6590                  arterial mean #2      NaN
# 4325     6702               Arterial BP Mean #2      NaN
# 4433     6927                  Arterial Mean #3      NaN
# 4726     7620                   BP Rt. Arm Mean      NaN
# 9530   220052      Arterial Blood Pressure mean     mmHg
# 9548   220181  Non Invasive Blood Pressure mean     mmHg
# 10501  225312                       ART BP mean     mmHg
# HEART_RATE
#        ITEMID        LABEL UNITNAME
# 211       211   Heart Rate      NaN
# 9524   220045   Heart Rate      bpm
# 11507  227018  HR_ApacheIV      bpm
# FRACTION_INSPIRED_OXYGEN
#        ITEMID                 LABEL UNITNAME
# 189       189       FiO2 (Analyzed)      NaN
# 190       190              FiO2 Set      NaN
# 675       727           Vision FiO2      NaN
# 1018     3420                  FIO2      NaN
# 1020     3422           FIO2 [Meas]      NaN
# 1196     1040            BIpap FIO2      NaN
# 1297     1206             HFO FIO2:      NaN
# 3239     1863              HFO-FiO2      NaN
# 3611     2518             HFO- FIO2      NaN
# 3910     2981                  FiO2      NaN
# 4472     7018             ecmo fio2      NaN
# 4486     7041        vapotherm fio2      NaN
# 4699     7570              FIO2 SET      NaN
# 9616   223835  Inspired O2 Fraction     None
# 11327  226754     FiO2ApacheIIValue        %
# 11498  227009     FiO2_ApacheIV_old     None
# 11499  227010         FiO2_ApacheIV        %
# RESPIRATORY_RATE
#        ITEMID                           LABEL  UNITNAME
# 570       614               Resp Rate (Spont)       NaN
# 571       615               Resp Rate (Total)       NaN
# 574       618                Respiratory Rate       NaN
# 575       619            Respiratory Rate Set       NaN
# 603       651                 Spon RR (Mech.)       NaN
# 605       653               Spont. Resp. Rate       NaN
# 2299     7884                              RR       NaN
# 2394     8113                      Resp. Rate       NaN
# 2779     3603                       Resp Rate       NaN
# 3252     1884                 Spont Resp rate       NaN
# 4352     6749                        total RR       NaN
# 9550   220210                Respiratory Rate  insp/min
# 10056  224688          Respiratory Rate (Set)  insp/min
# 10057  224689  Respiratory Rate (spontaneous)  insp/min
# 10058  224690        Respiratory Rate (Total)  insp/min
# 10151  224422                        Spont RR       bpm
# 11347  226774                 RRApacheIIValue  insp/min
# 11539  227050                     RR_ApacheIV  insp/min
# BODY_TEMPERATURE
#        ITEMID                   LABEL UNITNAME
# 626       676           Temperature C      NaN
# 627       677    Temperature C (calc)      NaN
# 628       678           Temperature F      NaN
# 629       679    Temperature F (calc)      NaN
# 2815     3652       Temp Axillary [F]      NaN
# 2817     3654         Temp Rectal [F]      NaN
# 4297     6643             Temp Rectal      NaN
# 9569   223761  Temperature Fahrenheit       ?F
# 9570   223762     Temperature Celsius       ?C
# 11351  226778       TempApacheIIValue       ?F
# 11543  227054   TemperatureF_ApacheIV       ?F
# WEIGHT
#        ITEMID                    LABEL UNITNAME
# 687       763             Daily Weight      NaN
# 2764     3580     Present Weight  (kg)      NaN
# 2765     3581     Present Weight  (lb)      NaN
# 2766     3582     Present Weight  (oz)      NaN
# 2848     3693                Weight Kg      NaN
# 10232  224639             Daily Weight       kg
# 11203  226512    Admission Weight (Kg)       kg
# 11213  226531  Admission Weight (lbs.)     None
# HEIGHT
#        ITEMID          LABEL UNITNAME
# 1401     1394  Height Inches      NaN
# 11304  226707         Height     Inch
# 11308  226730    Height (cm)       cm
# -----------------------------------------
# Loading Chart Events

# %%
#4: preprocessing_reduce_outputs.py
# !python related_code\\preprocessing_reduce_outputs.py
# Out:
# -----------------------------------------
# Load item definitions
# URINE_OUTPUT
# 5358              pacu out pacu urine
# 5371                  urine out other
# 5376          urine out straight cath
# 5390                      urine flush
# 5402                  cath lab output
#                      ...
# 11233                   straight cath
# 11297                        or urine
# 11301                      pacu urine
# 11302                        cath lab
# 11655    gu irrigant/urine volume out
# Name: LABEL, Length: 99, dtype: object
# -----------------------------------------
# Loading Output Events
# Remove admission and discharge days (since data on urine output is incomplete)
# Load ICU stays...

# %%
#5: preprocessing_merge_charts_outputs.py
# !python related_code\\preprocessing_merge_charts_outputs.py
# Out:
# Loading chart events...
# -----------------------------------------
# Compute BMI and GCS total...
# -----------------------------------------
# Loading output events...
# -----------------------------------------
# Create categorical variable...
# -----------------------------------------
# Save...
# -----------------------------------------
# Save data for logistic regression...

# %%
#6: preprocessing_CHARTS_PRESCRIPTIONS.py
# !python related_code\\preprocessing_CHARTS_PRESCRIPTIONS.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load charts and outputs...
# -----------------------------------------
# Load prescriptions...
# -----------------------------------------
# Link charts/outputs and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
#7: preprocessing_create_arrays.py
# !python related_code\\preprocessing_create_arrays.py
# Out:
# Loading icu_pat...
# Loading diagnoses/procedures...
# Loading charts/prescriptions...
# -----------------------------------------
# Create static array...
# Create label array...
# Create diagnoses/procedures and charts/prescriptions array...
# max_count 312
# Reindex df...
# done
# max_count 367
# Reindex df...
# done
# -----------------------------------------
# Split data into train/validate/test...
# Get patients corresponding to test ids
# -----------------------------------------
# Save...

# %%
# ran all the preprocessing, now let's look at the actual models

# %% [markdown]
# ## Modelling

# %%
#1 test_train_logreg.py
# !python related_code\\test_train_logreg.py
# Out:
# Loading data...
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\azaan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# Loading last vital signs measurements...
# -----------------------------------------
# Create array of static variables...
# Create static array...
# Create label array...
# -----------------------------------------
# Split data into train/validate/test...
# -----------------------------------------
# Fit logistic regression model...
# Bootstrap sample 0
# Evaluate...
# Bootstrap sample 1
# Evaluate...
# Bootstrap sample 2
# Evaluate...
# Bootstrap sample 3
# Evaluate...
# Bootstrap sample 4
# Evaluate...
# Bootstrap sample 5
# Evaluate...
# Bootstrap sample 6
# Evaluate...
# Bootstrap sample 7
# Evaluate...
# Bootstrap sample 8
# Evaluate...
# Bootstrap sample 9
# Evaluate...
# Bootstrap sample 10
# Evaluate...
# Bootstrap sample 11
# Evaluate...
# Bootstrap sample 12
# Evaluate...
# Bootstrap sample 13
# Evaluate...
# Bootstrap sample 14
# Evaluate...
# Bootstrap sample 15
# Evaluate...
# Bootstrap sample 16
# Evaluate...
# Bootstrap sample 17
# Evaluate...
# Bootstrap sample 18
# Evaluate...
# Bootstrap sample 19
# Evaluate...
# Bootstrap sample 20
# Evaluate...
# Bootstrap sample 21
# Evaluate...
# Bootstrap sample 22
# Evaluate...
# Bootstrap sample 23
# Evaluate...
# Bootstrap sample 24
# Evaluate...
# Bootstrap sample 25
# Evaluate...
# Bootstrap sample 26
# Evaluate...
# Bootstrap sample 27
# Evaluate...
# Bootstrap sample 28
# Evaluate...
# Bootstrap sample 29
# Evaluate...
# Bootstrap sample 30
# Evaluate...
# Bootstrap sample 31
# Evaluate...
# Bootstrap sample 32
# Evaluate...
# Bootstrap sample 33
# Evaluate...
# Bootstrap sample 34
# Evaluate...
# Bootstrap sample 35
# Evaluate...
# Bootstrap sample 36
# Evaluate...
# Bootstrap sample 37
# Evaluate...
# Bootstrap sample 38
# Evaluate...
# Bootstrap sample 39
# Evaluate...
# Bootstrap sample 40
# Evaluate...
# Bootstrap sample 41
# Evaluate...
# Bootstrap sample 42
# Evaluate...
# Bootstrap sample 43
# Evaluate...
# Bootstrap sample 44
# Evaluate...
# Bootstrap sample 45
# Evaluate...
# Bootstrap sample 46
# Evaluate...
# Bootstrap sample 47
# Evaluate...
# Bootstrap sample 48
# Evaluate...
# Bootstrap sample 49
# Evaluate...
# Bootstrap sample 50
# Evaluate...
# Bootstrap sample 51
# Evaluate...
# Bootstrap sample 52
# Evaluate...
# Bootstrap sample 53
# Evaluate...
# Bootstrap sample 54
# Evaluate...
# Bootstrap sample 55
# Evaluate...
# Bootstrap sample 56
# Evaluate...
# Bootstrap sample 57
# Evaluate...
# Bootstrap sample 58
# Evaluate...
# Bootstrap sample 59
# Evaluate...
# Bootstrap sample 60
# Evaluate...
# Bootstrap sample 61
# Evaluate...
# Bootstrap sample 62
# Evaluate...
# Bootstrap sample 63
# Evaluate...
# Bootstrap sample 64
# Evaluate...
# Bootstrap sample 65
# Evaluate...
# Bootstrap sample 66
# Evaluate...
# Bootstrap sample 67
# Evaluate...
# Bootstrap sample 68
# Evaluate...
# Bootstrap sample 69
# Evaluate...
# Bootstrap sample 70
# Evaluate...
# Bootstrap sample 71
# Evaluate...
# Bootstrap sample 72
# Evaluate...
# Bootstrap sample 73
# Evaluate...
# Bootstrap sample 74
# Evaluate...
# Bootstrap sample 75
# Evaluate...
# Bootstrap sample 76
# Evaluate...
# Bootstrap sample 77
# Evaluate...
# Bootstrap sample 78
# Evaluate...
# Bootstrap sample 79
# Evaluate...
# Bootstrap sample 80
# Evaluate...
# Bootstrap sample 81
# Evaluate...
# Bootstrap sample 82
# Evaluate...
# Bootstrap sample 83
# Evaluate...
# Bootstrap sample 84
# Evaluate...
# Bootstrap sample 85
# Evaluate...
# Bootstrap sample 86
# Evaluate...
# Bootstrap sample 87
# Evaluate...
# Bootstrap sample 88
# Evaluate...
# Bootstrap sample 89
# Evaluate...
# Bootstrap sample 90
# Evaluate...
# Bootstrap sample 91
# Evaluate...
# Bootstrap sample 92
# Evaluate...
# Bootstrap sample 93
# Evaluate...
# Bootstrap sample 94
# Evaluate...
# Bootstrap sample 95
# Evaluate...
# Bootstrap sample 96
# Evaluate...
# Bootstrap sample 97
# Evaluate...
# Bootstrap sample 98
# Evaluate...
# Bootstrap sample 99
# Evaluate...
# ------------------------------------------------
# Net variant: logistic regression
# Average Precision: 0.339 [0.287,0.391]
# AUROC: 0.75 [nan,nan]
# F1: 0.448 [0.393,0.503]
# PPV: 0.356 [0.297,0.415]
# NPV: 0.843 [0.796,0.889]
# Sensitivity: nan [nan,nan]
# Specificity: 0.724 [0.657,0.791]
# Done

# %%
#1 train.py
# !python related_code\\train.py
# Out:
# Load data...
#   0%|          | 0/80 [00:00<?, ?it/s]
#
# 0it [00:00, ?it/s]
# 0it [00:01, ?it/s]
#
#   1%|1         | 1/80 [00:01<02:20,  1.77s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:01, ?it/s]
#
#   2%|2         | 2/80 [00:03<02:11,  1.69s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:01, ?it/s]
#
#   4%|3         | 3/80 [00:05<02:09,  1.69s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:01, ?it/s]
#
#   5%|5         | 4/80 [00:06<02:06,  1.66s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:01, ?it/s]
#
#   6%|6         | 5/80 [00:08<02:02,  1.64s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#   8%|7         | 6/80 [00:10<02:11,  1.78s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#   9%|8         | 7/80 [00:13<02:30,  2.06s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  10%|#         | 8/80 [00:15<02:35,  2.16s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  11%|#1        | 9/80 [00:17<02:37,  2.22s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  12%|#2        | 10/80 [00:20<02:42,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  14%|#3        | 11/80 [00:22<02:43,  2.37s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  15%|#5        | 12/80 [00:25<02:40,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  16%|#6        | 13/80 [00:27<02:40,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  18%|#7        | 14/80 [00:30<02:44,  2.50s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:03, ?it/s]
#
#  19%|#8        | 15/80 [00:33<02:57,  2.73s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  20%|##        | 16/80 [00:35<02:48,  2.64s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  21%|##1       | 17/80 [00:38<02:41,  2.56s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  22%|##2       | 18/80 [00:41<02:40,  2.59s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  24%|##3       | 19/80 [00:43<02:37,  2.57s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  25%|##5       | 20/80 [00:45<02:31,  2.52s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  26%|##6       | 21/80 [00:48<02:29,  2.54s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  28%|##7       | 22/80 [00:50<02:24,  2.49s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  29%|##8       | 23/80 [00:53<02:16,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  30%|###       | 24/80 [00:55<02:10,  2.34s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  31%|###1      | 25/80 [00:57<02:10,  2.38s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  32%|###2      | 26/80 [01:00<02:09,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  34%|###3      | 27/80 [01:02<02:06,  2.38s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  35%|###5      | 28/80 [01:05<02:05,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  36%|###6      | 29/80 [01:07<02:06,  2.49s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  38%|###7      | 30/80 [01:10<02:06,  2.53s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  39%|###8      | 31/80 [01:12<02:01,  2.48s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  40%|####      | 32/80 [01:15<01:59,  2.49s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  41%|####1     | 33/80 [01:17<01:53,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  42%|####2     | 34/80 [01:19<01:48,  2.37s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  44%|####3     | 35/80 [01:22<01:45,  2.35s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  45%|####5     | 36/80 [01:24<01:44,  2.37s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  46%|####6     | 37/80 [01:26<01:40,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  48%|####7     | 38/80 [01:28<01:37,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  49%|####8     | 39/80 [01:31<01:35,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  50%|#####     | 40/80 [01:33<01:32,  2.32s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  51%|#####1    | 41/80 [01:35<01:30,  2.31s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  52%|#####2    | 42/80 [01:38<01:27,  2.32s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  54%|#####3    | 43/80 [01:40<01:25,  2.31s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  55%|#####5    | 44/80 [01:42<01:24,  2.35s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  56%|#####6    | 45/80 [01:45<01:22,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  57%|#####7    | 46/80 [01:47<01:19,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  59%|#####8    | 47/80 [01:49<01:16,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  60%|######    | 48/80 [01:52<01:14,  2.32s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  61%|######1   | 49/80 [01:54<01:11,  2.32s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  62%|######2   | 50/80 [01:56<01:09,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  64%|######3   | 51/80 [01:59<01:07,  2.32s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  65%|######5   | 52/80 [02:02<01:09,  2.47s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  66%|######6   | 53/80 [02:04<01:04,  2.41s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  68%|######7   | 54/80 [02:06<01:02,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  69%|######8   | 55/80 [02:09<01:02,  2.48s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  70%|#######   | 56/80 [02:11<00:58,  2.44s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  71%|#######1  | 57/80 [02:14<00:55,  2.41s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  72%|#######2  | 58/80 [02:16<00:53,  2.44s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  74%|#######3  | 59/80 [02:18<00:51,  2.44s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  75%|#######5  | 60/80 [02:21<00:48,  2.41s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  76%|#######6  | 61/80 [02:23<00:44,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  78%|#######7  | 62/80 [02:26<00:43,  2.44s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  79%|#######8  | 63/80 [02:28<00:40,  2.40s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  80%|########  | 64/80 [02:30<00:38,  2.41s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  81%|########1 | 65/80 [02:33<00:35,  2.39s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  82%|########2 | 66/80 [02:35<00:33,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  84%|########3 | 67/80 [02:37<00:30,  2.33s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  85%|########5 | 68/80 [02:40<00:28,  2.34s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  86%|########6 | 69/80 [02:42<00:25,  2.34s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  88%|########7 | 70/80 [02:44<00:23,  2.35s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  89%|########8 | 71/80 [02:47<00:21,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  90%|######### | 72/80 [02:49<00:18,  2.35s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  91%|#########1| 73/80 [02:51<00:16,  2.35s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  92%|#########2| 74/80 [02:54<00:14,  2.36s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  94%|#########3| 75/80 [02:57<00:12,  2.47s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  95%|#########5| 76/80 [02:59<00:09,  2.45s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  96%|#########6| 77/80 [03:01<00:07,  2.42s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  98%|#########7| 78/80 [03:04<00:04,  2.48s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
#  99%|#########8| 79/80 [03:07<00:02,  2.62s/it]
#
# 0it [00:00, ?it/s]
# 0it [00:02, ?it/s]
#
# 100%|##########| 80/80 [03:09<00:00,  2.61s/it]
# 100%|##########| 80/80 [03:09<00:00,  2.37s/it]
# -----------------------------------------
# Train...
# Saving...
# Done

# %%
#1 test.py
# finally solved an issue by decreasing batch size in hyperparameters.py
# !python related_code\\test.py
