# %%
import zipfile
with zipfile.ZipFile('mimic-iii-clinical-database-1.4.zip', 'r') as zip_ref:
    zip_ref.extractall('MIMIC-III Clinical Database')

# %%
import os
import csv
import numpy as np

# %% [markdown]
# ## Preprocessing

# %%
# from pyhealth.datasets import MIMIC3Dataset

# mimic3_ds = MIMIC3Dataset(
#         root="https://storage.googleapis.com/pyhealth/Synthetic_MIMIC-III/",
#         tables=["DIAGNOSES_ICD", "PROCEDURES_ICD", "PRESCRIPTIONS"],
#         code_mapping={"NDC": ("ATC", {"target_kwargs": {"level": 3}})},
# )

# # we show the statistics below.
# mimic3_ds

# %%
os.getcwd()

# %%
# extract all gz files and delete old ones
import gzip
import os

def extract_gz_files(directory):
    """
    Extract all .gz files in a given directory into the current folder, and delete the original .gz files.

    Args:
    - directory (str): the path to the directory containing the .gz files

    Returns:
    - None
    """

    # Get a list of all .gz files in the directory
    gz_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.gz')]

    # Extract each .gz file into the current folder and delete the original file
    for gz_file in gz_files:
        with gzip.open(gz_file, 'rb') as f_in:
            with open(os.path.splitext(gz_file)[0], 'wb') as f_out:
                f_out.write(f_in.read())
        # os.remove(gz_file)

# %%
def remove_gz_files(directory):
    gz_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.gz')]

    # Delete the gz file
    for gz_file in gz_files:
        os.remove(gz_file)

# %%
extract_gz_files('MIMIC-III Clinical Database')

# %%
# remove_gz_files('MIMIC-III Clinical Database')

# %%
# having issues because of lowercase headers in the mimic-iii file, so i have some code
# to make all the headers into capital letters here:

import os
import csv

# Specify the path to your folder of CSV files
folder_path = 'C:/Users/azaan/OneDrive/Documents/GitHub/CS598-Healthcare-Project/MIMIC-III Clinical Database/'

# Loop through each CSV file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        # Open the CSV file for reading
        with open(file_path, 'r') as csv_file:
            reader = csv.reader(csv_file)

            # Create a new list to hold the capitalized header row
            new_rows = []

            # Loop through each row in the CSV file
            for i, row in enumerate(reader):

                # Capitalize the header row
                if i == 0:
                    new_row = [cell.upper() for cell in row]
                    new_rows.append(new_row)

                # Keep all other rows the same
                else:
                    new_rows.append(row)

        # Open the CSV file for writing
        with open(file_path, 'w', newline='') as csv_file:
            writer = csv.writer(csv_file)

            # Write the new rows to the CSV file
            writer.writerows(new_rows)

# %%
# I am going to tr and run some files related_code
# Order is important so I will write the order I do them

#1: preproceeing_ICU_PAT_ADMIT.py
# !python related_code/preprocessing_ICU_PAT_ADMIT.py
# Out:
# Load ICU stays...
# -----------------------------------------
# Load patients...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load services...
# -----------------------------------------
# Link icustays and patients tables...
# Compute number of recent admissions...
# 100%|████████████████████████████████████| 43126/43126 [01:04<00:00, 673.21it/s]
# -----------------------------------------
# Link icu_pat and admissions tables...
# SUBJECT_ID                  0
# HADM_ID                     0
# ICUSTAY_ID                  0
# INTIME                      0
# OUTTIME                     0
# LOS                         0
# GENDER_M                    0
# NUM_RECENT_ADMISSIONS       0
# AGE                         0
# POSITIVE                    0
# ADMITTIME                   0
# ADMISSION_TYPE              0
# ADMISSION_LOCATION          0
# INSURANCE                   0
# MARITAL_STATUS           1776
# ...

# %%
#2: preprocessing chart perscriptions
# !python related_code/preprocessing_DIAGNOSES_PROCEDURES.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load admissions...
# -----------------------------------------
# Load diagnoses and procedures...
# -----------------------------------------
# Link diagnoses/procedures and admissions tables...
# Link diagnoses/procedures and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
# export chart events again, issue with it
import gzip
import csv

input_file = "MIMIC-III Clinical Database/CHARTEVENTS.csv.gz"
output_file = "MIMIC-III Clinical Database/CHARTEVENTS.csv"

with gzip.open(input_file, "rt") as gz_file, open(output_file, "w") as csv_file:
    reader = csv.reader(gz_file)
    writer = csv.writer(csv_file)
    for row in reader:
        writer.writerow(row)

# %%
#3: preprocessing_reduce_charts.py
# !python related_code/preprocessing_reduce_charts.py
# Out:
# -----------------------------------------
# Load item definitions
# GCS_EYE_OPENING
#        ITEMID                LABEL UNITNAME
# 448       184          Eye Opening      NaN
# 9679   227011      GCSEye_ApacheIV      NaN
# 11494  220739    GCS - Eye Opening      NaN
# 12481  226756  GCSEyeApacheIIValue      NaN
# GCS_VERBAL_RESPONSE
#        ITEMID                   LABEL UNITNAME
# 1491      723         Verbal Response      NaN
# 9682   227014      GCSVerbal_ApacheIV      NaN
# 12037  223900   GCS - Verbal Response      NaN
# 12483  226758  GCSVerbalApacheIIValue      NaN
# GCS_MOTOR_RESPONSE
#        ITEMID                  LABEL UNITNAME
# 681       454         Motor Response      NaN
# 9680   227012      GCSMotor_ApacheIV      NaN
# 12038  223901   GCS - Motor Response      NaN
# 12482  226757  GCSMotorApacheIIValue      NaN
# GCS_TOTAL
#        ITEMID             LABEL UNITNAME
# 462       198         GCS Total      NaN
# 12480  226755  GcsApacheIIScore     None
# DIASTOLIC_BP
# ...

# %%
# export chart events again, issue with it
import gzip
import csv

input_file = "MIMIC-III Clinical Database/OUTPUTEVENTS.csv.gz"
output_file = "MIMIC-III Clinical Database/OUTPUTEVENTS.csv"

with gzip.open(input_file, "rt") as gz_file, open(output_file, "w") as csv_file:
    reader = csv.reader(gz_file)
    writer = csv.writer(csv_file)
    for row in reader:
        writer.writerow(row)

# %%
#4: preprocessing_reduce_outputs.py
# !python related_code/preprocessing_reduce_outputs.py
# Out:
# -----------------------------------------
# Load item definitions
# URINE_OUTPUT
# 4397             urine out other
# 4402     urine out straight cath
# 4416                 urine flush
# 4428             cath lab output
# 4436                cath lab out
#                   ...
# 11905              straight cath
# 12182               ed urine out
# 12293                   or urine
# 12297                 pacu urine
# 12298                   cath lab
# Name: LABEL, Length: 99, dtype: object
# -----------------------------------------
# Loading Output Events
# Remove admission and discharge days (since data on urine output is incomplete)
# Load ICU stays...

# %%
#5: preprocessing_merge_charts_outputs.py
# !python related_code/preprocessing_merge_charts_outputs.py
# Out:
# Loading chart events...
# -----------------------------------------
# Compute BMI and GCS total...
# -----------------------------------------
# Loading output events...
# -----------------------------------------
# Create categorical variable...
# -----------------------------------------
# Save...
# -----------------------------------------
# Save data for logistic regression...

# %%
#6: preprocessing_CHARTS_PRESCRIPTIONS.py
# !python related_code/preprocessing_CHARTS_PRESCRIPTIONS.py
# Out:
# Loading icu_pat...
# -----------------------------------------
# Load charts and outputs...
# -----------------------------------------
# Load prescriptions...
# -----------------------------------------
# Link charts/outputs and icu_pat tables...
# Drop duplicates...
# Map rare codes to OTHER...
# -----------------------------------------
# Save...

# %%
#7: preprocessing_create_arrays.py
# !python related_code/preprocessing_create_arrays.py
# Out:
# Loading icu_pat...
# Loading diagnoses/procedures...
# Loading charts/prescriptions...
# -----------------------------------------
# Create static array...
# Index(['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'INTIME', 'OUTTIME', 'LOS',
#        'GENDER_M', 'NUM_RECENT_ADMISSIONS', 'AGE', 'POSITIVE', 'PRE_ICU_LOS',
#        'ELECTIVE_SURGERY', 'ADMISSION_LOCATION_Clinic Referral/Premature',
#        'ADMISSION_LOCATION_Emergency Room Admit',
#        'ADMISSION_LOCATION_Other/Unknown',
#        'ADMISSION_LOCATION_Phys Referral/Normal Deli',
#        'ADMISSION_LOCATION_Transfer From Hosp/Extram',
#        'ADMISSION_LOCATION_Transfer From Skilled Nur', 'INSURANCE_Government',
#        'INSURANCE_Medicaid', 'INSURANCE_Medicare', 'INSURANCE_Private',
#        'INSURANCE_Self Pay', 'MARITAL_STATUS_Married/Life Partner',
#        'MARITAL_STATUS_Other/Unknown', 'MARITAL_STATUS_Single',
#        'MARITAL_STATUS_Widowed/Divorced/Separated', 'ETHNICITY_Asian',
# ...

# %%
# ran all the preprocessing, now let's look at the actual models

# %% [markdown]
# ## Modelling

# %%
# !pip install torchdiffeq

# %%
#1 test_train_logreg.py
# !python related_code/test_train_logreg.py
# Out:
# Loading data...
# Loading last vital signs measurements...
# -----------------------------------------
# Create array of static variables...
# Create static array...
# Create label array...
# -----------------------------------------
# Split data into train/validate/test...
# -----------------------------------------
# Fit logistic regression model...
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Bootstrap sample 0
# Evaluate...
# ...

# %% [markdown]
# ## Testing different methods!

# %%
# My own MODULES !!!

# %%
# Pre-trained this model before testing here for demo
# train my vanilla rnn
# !python related_code/train.py
# Out:
# Load data...
# -----------------------------------------
# Train...
# ...
# 100%|█████████████████████████████████████████████| 3/3 [00:25<00:00,  8.35s/it]
# Saving...
# Done

# %%
# vanilla rnn
# !python related_code/test.py
# Out:
# Load data...
# ...
# Evaluate...
# Bootstrap sample 0
# 100%|███████████████████████████████████████████| 35/35 [00:00<00:00, 57.44it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Bootstrap sample 1
# 100%|███████████████████████████████████████████| 36/36 [00:00<00:00, 61.09it/s]
# ...

# %%
# Pre-trained this model before testing here for demo
# rnn + logistic regression training
# !python related_code/train.py

# %%
# rnn + logistic regression test
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
# 100%|███████████████████████████████████████████| 35/35 [00:00<00:00, 60.73it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Bootstrap sample 1
# 100%|███████████████████████████████████████████| 36/36 [00:00<00:00, 61.74it/s]
# ...

# %%
# GIVEN MODULES !!!
# finally solved an issue by decreasing batch size in hyperparameters.py
# plan is to run:
#1 ode, rnn, attention YY
#2 ode, rnn YY
#3 rnn ode time decay + attention YY
#4 rnn ode time decay YY
#5 rnn exp time decay + attention YY

# %%
# ode rnn attention
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
#   0%|                                                    | 0/35 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/torchdiffeq/_impl/misc.py:11: UserWarning: Euler: Unexpected arguments {'max_num_steps': 1000}
#   warnings.warn('{}: Unexpected arguments {}'.format(solver.__class__.__name__, unused_kwargs))
# 100%|███████████████████████████████████████████| 35/35 [00:01<00:00, 18.25it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# ode rnn
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
#   0%|                                                    | 0/35 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/torchdiffeq/_impl/misc.py:11: UserWarning: Euler: Unexpected arguments {'max_num_steps': 1000}
#   warnings.warn('{}: Unexpected arguments {}'.format(solver.__class__.__name__, unused_kwargs))
# 100%|███████████████████████████████████████████| 35/35 [00:01<00:00, 18.55it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# ode decay rnn attention
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
#   0%|                                                    | 0/35 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/torchdiffeq/_impl/misc.py:11: UserWarning: Euler: Unexpected arguments {'max_num_steps': 1000}
#   warnings.warn('{}: Unexpected arguments {}'.format(solver.__class__.__name__, unused_kwargs))
# 100%|███████████████████████████████████████████| 35/35 [00:25<00:00,  1.35it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# birnn time decay attention
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
# 100%|███████████████████████████████████████████| 35/35 [00:09<00:00,  3.82it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Bootstrap sample 1
# 100%|███████████████████████████████████████████| 36/36 [00:09<00:00,  3.81it/s]
# ...

# %%
# birnn time decay
# !python related_code/test.py
# Out:
# Load data...
# Evaluate...
# Bootstrap sample 0
# 100%|███████████████████████████████████████████| 35/35 [00:09<00:00,  3.79it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Bootstrap sample 1
# 100%|███████████████████████████████████████████| 36/36 [00:09<00:00,  3.77it/s]
# ...

# %%
avpre_vec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3997/1475446025.py in <module>
# ----> 1 avpre_vec
#
# NameError: name 'avpre_vec' is not defined
